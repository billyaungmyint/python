# %%
import pandas as pd
import numpy as np
import spacy
from spacy.pipeline import EntityRuler

#!spacy download en_core_web_sm
#nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('XXXX the first big office in Hong Kong')
print(doc.ents) #default entities
# Out:
# (first, Hong Kong)

# %%
patterns = [{"label":"ORG" , "pattern":"XXXX"}]
ruler = nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)
doc2 = nlp('XXXX the first big office in Hong Kong')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 patterns = [{"label":"ORG" , "pattern":"XXXX"}]
# ----> 2 ruler = nlp.add_pipe("entity_ruler")
#       3 ruler.add_patterns(patterns)
#       4 doc2 = nlp('XXXX the first big office in Hong Kong')
#
# File /usr/local/lib/python3.8/dist-packages/spacy/language.py:782, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     780 name = name if name is not None else factory_name
#     781 if name in self.component_names:
# --> 782     raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     783 # Overriding pipe name in the config is not supported and will be ignored.
#     784 if "name" in config:
#
# ...

# %%
print(doc.ents)
# Out:
# (first, Hong Kong)
