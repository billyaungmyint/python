# %%
import numpy as np
import pandas as pd
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
txt = "Rice, the staple food of about 50% of the global population and consumed at the rate of one-fifth of the total global calorie count, is grown in wetland systems."
doc = nlp(txt)

# %%
for token in doc:
    print(token.text , token.lemma_)
# Out:
# Rice Rice
# , ,
# the the
# staple staple
# food food
# of of
# about about
# 50 50
# % %
# of of
# the the
# global global
# population population
# and and
# consumed consume
# at at
# the the
# rate rate
# of of
# one one
# - -
# fifth fifth
# of of
# the the
# total total
# global global
# calorie calorie
# count count
# , ,
# is be
# grown grow
# in in
# wetland wetland
# systems system
# . .
