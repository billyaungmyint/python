# %%
import pandas as pd
import numpy as np
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# 2023-06-07 08:58:02.668227: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-07 08:58:02.668255: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-07 08:58:02.668273: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (5a6b3f84-2598-4c46-8952-6d45fe195d6f): /proc/driver/nvidia/version does not exist
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 import numpy as np
#       3 import spacy
# ----> 4 nlp = spacy.load('en_core_web_sm')
#
# File /usr/local/lib/python3.8/dist-packages/spacy/__init__.py:54, in load(name, vocab, disable, enable, exclude, config)
# ...

# %%
# https://news.mongabay.com/2022/11/biodiversity-credit-market-must-learn-from-carbon-offset-mistakes-commentary/
text = 'We must act quickly to reverse this damaging trend and protect our planet. Voluntary biodiversity credits – proactive investments from companies, nations and even individuals to protect wildlife – could be a powerful tool, but only if used correctly. The biodiversity credit market must learn the lessons from the carbon credit market and build a transparent, accountable and inclusive system from the beginning.'
doc = nlp(text)

# %%
print(type(doc))
# Out:
# <class 'spacy.tokens.doc.Doc'>

# %%
#split into sentences
sentences = [sentence.text for sentence in doc.sents] 
print(sentences)
# Out:
# ['We must act quickly to reverse this damaging trend and protect our planet.', 'Voluntary biodiversity credits – proactive investments from companies, nations and even individuals to protect wildlife – could be a powerful tool, but only if used correctly.', 'The biodiversity credit market must learn the lessons from the carbon credit market and build a transparent, accountable and inclusive system from the beginning.']

# %%
#removing punctuation in spacy
token_without_punc = [token for token in doc if not token.is_punct ]
print(token_without_punc)
# Out:
# [We, must, act, quickly, to, reverse, this, damaging, trend, and, protect, our, planet, Voluntary, biodiversity, credits, proactive, investments, from, companies, nations, and, even, individuals, to, protect, wildlife, could, be, a, powerful, tool, but, only, if, used, correctly, The, biodiversity, credit, market, must, learn, the, lessons, from, the, carbon, credit, market, and, build, a, transparent, accountable, and, inclusive, system, from, the, beginning]
