# %%
import numpy as np
import pandas as pd
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('Singaporean Peter Lim is looking to buy Valencia Football Club in Spain')

# %%
for token in doc:
    print(token.text , token.ent_type_)
# Out:
# Singaporean NORP
# Peter PERSON
# Lim PERSON
# is
# looking
# to
# buy
# Valencia ORG
# Football ORG
# Club ORG
# in
# Spain GPE
