# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)

# %%
import spacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nlp = spacy.load("en_core_web_sm") #load the english model

# %%
#assign the default stopwords list to a variable
#STOP_WORDS = spacy.lang.en.stop_words.STOP_WORDS
STOP_WORDS=spacy.lang.en.stop_words.STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'above', "'re", 'while', 'except', 'three', 'therein', 'nobody', 'six', 'say', 'whole', 'least', 'what', 'often', 'moreover', 'must', 'whose', 'i', 'been', 'some', 'be', 're', 'about', 'forty', 'yours', 'show', 'others', 'me', 'whether', 'in', 'sometime', 'your', 'formerly', 'either', 'because', 'seems', 'front', 'do', 'of', 'those', 'next', 'go', 'beforehand', 'they', 'sometimes', 'whom', 'various', 'whence', 'into', 'so', 'or', 'a', 'between', 'could', 'hereupon', 'more', 'all', 'whatever', 'four', 'five', "'ll", 'them', 'here', 'see', 'ca', 'n’t', 'whereupon', 'who', 'give', 'few', 'him', 'hundred', 'most', 'when', 'move', 'side', 'twelve', 'should', 'even', 'becoming', 'indeed', 'but', 'rather', 'among', 'will', 'am', 'hence', 'another', 'its', 'make', 'first', 'also', 'only', 'due', 'may', 'from', 'beyond', 'name', 'thru', 'noone', 'whereby', 'whereafter', 'himself', 'much', 'throughout', 'nothing', 'same', 'nor', 'done', 'latter', 'twenty', 'alone', 'meanwhile', 'their', 'thereby', 'amongst', 'to', 'without', '’s', 'can', 'please', 'yourselves', 'she', 'whoever', 'became', 'on', 'other', 'did', 'an', 'someone', 'now', 'before', 'quite', 'behind', 'afterwards', 'toward', 'across', 'almost', 'many', 'anywhere', 'has', 'off', "n't", 'using', 'one', 'as', 'every', 'each', 'nine', 'together', 'anyone', 'not', 'sixty', 'beside', 'around', 'these', "'s", 'anyway', 'does', 'doing', 'nevertheless', 'the', 'after', "'m", 'and', 'myself', 'empty', 'both', 'hers', 'mostly', 'below', 'until', '’ve', 'then', 'neither', 'too', 'yet', 'something', 'besides', 'herself', 'serious', 'seemed', 'no', 'being', 'fifteen', 'whenever', 'hereby', 'although', 'fifty', 'with', 'over', '‘re', 'bottom', 'latterly', 'through', 'were', 'eight', 'everyone', 'none', 'really', 'my', 'regarding', 'themselves', 'thereupon', 'everywhere', 'anyhow', '‘s', 'whither', '‘d', 'already', 'there', 'ever', '’m', 'two', '’ll', '’re', 'his', 'made', '‘ve', 'than', 'which', 'he', 'never', 'if', 'her', 'you', 'ourselves', 'at', 'anything', 'ten', 'seeming', 'is', 'per', 'n‘t', 'itself', '‘ll', 'otherwise', 'less', 'used', 'else', 'amount', 'somewhere', 'that', 'against', 'ours', 'thence', 'elsewhere', 'take', 'get', 'for', 'further', 'unless', 'eleven', 'might', 'seem', 'nowhere', "'d", "'ve", 'very', 'full', 'was', 'are', 'out', 'along', 'would', 'namely', 'just', 'wherever', 'again', 'any', 'up', 'towards', 'perhaps', 'put', 'therefore', 'everything', 'though', 'such', 'still', 'third', 'own', 'during', 'somehow', 'once', 'within', 'why', 'keep', 'back', 'under', 'we', 'upon', 'several', 'how', 'down', 'by', 'mine', 'hereafter', 'yourself', 'top', 'becomes', 'however', 'cannot', 'thereafter', 'former', 'wherein', 'this', 'since', 'onto', 'it', 'become', 'call', 'herein', 'have', 'thus', 'well', 'always', 'had', '’d', 'part', 'our', 'enough', 'via', 'us', 'whereas', 'where', '‘m', 'last'}

# %% [markdown]
# Add stopwords

# %%
#nlp.Defaults.stop_words.add("add")
nlp.Defaults.stop_words.add("newt")

# %%
#nlp.Defaults.stop_words |= {"stop","word",}  #add stopwords
nlp.Defaults.stop_words |= {"stop","word",}

# %% [markdown]
# Remove stopwords

# %%
#nlp.Defaults.stop_words -= {"stop", "word"}
nlp.Defaults.stop_words -={"stop","word"}

# %%
doc = nlp(u"I love to travel and try new cuisines")
