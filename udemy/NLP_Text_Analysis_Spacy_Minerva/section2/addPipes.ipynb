# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import spacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nlp = spacy.load("en_core_web_sm") #load the english model

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# Add textcat to the pipeline (for categorising text))

# %%
import en_core_web_sm # or skip, see below
from spacy.pipeline.textcat import Config, single_label_cnn_config

nlp = en_core_web_sm.load() # or nlp=spacy.load("en_core_web_sm")

config = Config().from_str(single_label_cnn_config)
if "textcat" not in nlp.pipe_names:
     nlp.add_pipe('textcat', config=config, last=True)

nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'textcat']
