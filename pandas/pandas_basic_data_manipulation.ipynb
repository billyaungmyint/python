# %% [markdown]
# # Pandas Basic Data Manipulation

# %% [markdown]
# ### basic Pandas

# %%
import pandas as pd
df = pd.read_csv('../NUS/ChallengerSales.csv')
df.head(5)
# Out:
#     Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0  6-Mar  Mon    Morning  Female        High             4     136.97
# 1  6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar  Mon  Afternoon    Male      Medium             4     147.32
#
#    HighItem Member Region
# 0     79.97    Yes   West
# 1     25.55     No   West
# 2     90.47    Yes   West
# 3      6.82     No   East
# 4     83.21    Yes   West

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.columns)
print(df.shape)
print(df.size)
print(df.info())
print(df.describe())
print(df.max())
print(df.min())
print(df.drop_duplicates())
print(df.sort_values(['Date','Gender']))
print(df.value_counts())
# Out:
# Index(['Date', 'Day', 'Time', 'Gender', 'BuyCategory', 'ItemsOrdered',
#        'TotalCost', 'HighItem', 'Member', 'Region'],
#       dtype='object')
# (400, 10)
# 4000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          400 non-null    object
#  1   Day           400 non-null    object
#  2   Time          400 non-null    object
#  3   Gender        400 non-null    object
#  4   BuyCategory   400 non-null    object
#  5   ItemsOrdered  400 non-null    int64
#  6   TotalCost     400 non-null    float64
#  7   HighItem      400 non-null    float64
#  8   Member        400 non-null    object
#  9   Region        400 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 31.4+ KB
# None
#        ItemsOrdered   TotalCost    HighItem
# count    400.000000  400.000000  400.000000
# ...

# %%
import pandas as pd
employees = pd.read_csv("../data/employees.csv")
employees.head(5)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
male = employees[(employees['Gender'] == 'Male') & (employees['Salary'] > 100000)].drop_duplicates('Salary')
male.count()
#male['Salary'].sort_values(ascending = False)
# Out:
# First Name           162
# Gender               177
# Start Date           177
# Last Login Time      177
# Salary               177
# Bonus %              177
# Senior Management    162
# Team                 167
# dtype: int64

# %%
male = employees[employees['Gender'].isin(['Male'])]
male
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas   Male  3/31/1996         6:53 AM   61933    4.170
# 3        Jerry   Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis   Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip   Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
filter1 = employees["Gender"].isin(["Female"])
filter2 = employees["Team"].isin(["Engineering", "Distribution", "Finance" ])
print(filter1)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
gender = ['Male','Female']
gender
marketing_finance = employees.query("Team in ['Marketing','Finance']")
marketing_finance.sort_values(["Salary","Senior Management"] , ascending = [False,False])
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 160      Kathy  Female  3/18/2000         7:26 PM  149563   16.991
# 740    Russell     NaN   5/9/2009        11:59 AM  149456    3.533
# 765      Alice     NaN  4/23/1995         6:35 AM  148339   11.479
# 318        Roy    Male   8/6/2006         7:52 AM  148225    1.841
# ..         ...     ...        ...             ...     ...      ...
# 331     Evelyn  Female   9/3/1983         1:58 PM   36759   17.269
# 809     George    Male  9/27/1995         5:04 PM   36749   19.754
# 201   Kimberly  Female  7/15/1997         5:57 AM   36643    7.953
# 418      Julia  Female   3/2/1982        12:52 PM   36403    2.664
# 650    Cynthia  Female   7/5/1986         1:24 AM   35381   11.749
#
#     Senior Management       Team
# 644             False    Finance
# 160              True    Finance
# 740             False  Marketing
# ...
