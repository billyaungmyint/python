# %% [markdown]
# # Pandas modifying columns and exporting datasets

# %%
import pandas as pd
df = pd.read_csv('../NUS/ChallengerSales.csv')
df.head(5)
# Out:
#     Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0  6-Mar  Mon    Morning  Female        High             4     136.97
# 1  6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar  Mon  Afternoon    Male      Medium             4     147.32
#
#    HighItem Member Region
# 0     79.97    Yes   West
# 1     25.55     No   West
# 2     90.47    Yes   West
# 3      6.82     No   East
# 4     83.21    Yes   West

# %%
df['AvgCostItems'] = 0

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Time', 'Gender', 'BuyCategory', 'ItemsOrdered',
#        'TotalCost', 'HighItem', 'Member', 'Region', 'AvgCostItems'],
#       dtype='object')

# %%
df['AvgCostItems'] = round(df['TotalCost'] / df['ItemsOrdered'] , 2)
df.head(5)
# Out:
#     Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0  6-Mar  Mon    Morning  Female        High             4     136.97
# 1  6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar  Mon  Afternoon    Male      Medium             4     147.32
#
#    HighItem Member Region  AvgCostItems
# 0     79.97    Yes   West         34.24
# 1     25.55     No   West         25.55
# 2     90.47    Yes   West         22.79
# 3      6.82     No   East          6.82
# 4     83.21    Yes   West         36.83

# %%
df.drop(columns = ['AvgCostItems'])
# Out:
#        Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0     6-Mar  Mon    Morning  Female        High             4     136.97
# 1     6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2     6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3     6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4     6-Mar  Mon  Afternoon    Male      Medium             4     147.32
# ..      ...  ...        ...     ...         ...           ...        ...
# 395  25-Jun  Sat  Afternoon    Male      Medium             6     268.39
# 396  25-Jun  Sat  Afternoon  Female      Medium             3     169.11
# 397  25-Jun  Sat  Afternoon    Male      Medium             6     242.46
# 398  25-Jun  Sat  Afternoon    Male      Medium             4     168.64
# 399  25-Jun  Sat  Afternoon  Female         Low             1     107.59
#
#      HighItem Member Region
# 0       79.97    Yes   West
# 1       25.55     No   West
# ...

# %%
#df.drop(columns = ['AvgCostItems'] , inplace =True)
df.head(5)
# Out:
#     Date  Day       Time  Gender BuyCategory  ItemsOrdered  TotalCost  \
# 0  6-Mar  Mon    Morning  Female        High             4     136.97
# 1  6-Mar  Mon    Morning  Female      Medium             1      25.55
# 2  6-Mar  Mon  Afternoon  Female      Medium             5     113.95
# 3  6-Mar  Mon  Afternoon  Female         Low             1       6.82
# 4  6-Mar  Mon  Afternoon    Male      Medium             4     147.32
#
#    HighItem Member Region
# 0     79.97    Yes   West
# 1     25.55     No   West
# 2     90.47    Yes   West
# 3      6.82     No   East
# 4     83.21    Yes   West

# %%
df['AvgCostItems'] = round(df['TotalCost'] / df['ItemsOrdered'] , 2)
df.to_csv('outdata.csv' , sep=',' ,index = False, header = True)
